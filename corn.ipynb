# %%
import tensorflow as tf
from tensorflow.keras import models,layers

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
IMAGE_SIZE=256
BATCH_SIZE=64
CHANNELS=3
EPOCHS=50

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(r"D:\project dataset\DATASET\Corn",shuffle=True,
                                                    image_size=(IMAGE_SIZE,IMAGE_SIZE),
                                                    batch_size=BATCH_SIZE)
# Out:
# Found 16261 files belonging to 5 classes.

# %%
for images, labels in dataset.take(1):

    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(f"Class: {labels[i].numpy()}")
        plt.axis("off")

    plt.show()

# %%
shuffle_size=1000
suffle_ds=dataset.shuffle(shuffle_size,seed=12)

# %%
train_size=0.8

# %%
#train 80%
#validate 10%
#test 10%

# %%
train_data=int(len(dataset)*train_size)
train_dataset=dataset.take(train_data)
test_dataset=dataset.skip(train_data)

# %%
val_size=int((len(test_dataset)/2))

# %%
val_dataset=test_dataset.take(val_size)
test_dataset=test_dataset.skip(val_size)

# %%
# print(len(dataset))
# print(len(train_dataset))
# print(len(val_dataset))
# print(len(test_dataset))

# %%
train_dataset=train_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_dataset=val_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset=test_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_rescale=tf.keras.Sequential([layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
                     layers.experimental.preprocessing.Rescaling(1.0/255)])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    #layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    #layers.experimental.preprocessing.Rescaling(1.0/255),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomTranslation(0.2, 0.2),
    layers.experimental.preprocessing.RandomContrast(0.2),
])

# %%
#augmented_train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x), y))

# %%
#validation_dataset = val_dataset.map(lambda x, y: (resize_rescale(x), y))

# %%
#test_dataset = test_dataset.map(lambda x, y: (resize_rescale(x), y))

# %%
for batch in train_dataset.take(1):
    images, labels = batch
    print("Shape of images in a batch:", images.shape)
# Out:
# Shape of images in a batch: (64, 256, 256, 3)

# %%
n_class=5
input_shape=(BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
model=models.Sequential([resize_rescale,data_augmentation,layers.Conv2D(32,(3,3),activation='relu',input_shape=input_shape),
                         layers.MaxPooling2D((2,2)),
                         layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
                         layers.MaxPooling2D((2,2)),
                         layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
                         layers.MaxPooling2D((2,2)),
                         layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
                         layers.MaxPooling2D((2,2)),
                         layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
                         layers.MaxPooling2D((2,2)),
                         layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
                         layers.MaxPooling2D((2,2)),
                         layers.Flatten(),
                         layers.Dense(64,activation='relu'),
                         layers.Dense(n_class,activation='softmax'),
                        ])
model.build(input_shape=input_shape)

# %%
model.compile(
             optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
             metrics=['accuracy'])

# %%
history = model.fit(
    train_dataset,
    batch_size=BATCH_SIZE,
    validation_data=val_dataset,
    verbose=1,
    epochs=20,
)
# Out:
# Epoch 1/20
# 204/204 [==============================] - 586s 3s/step - loss: 0.7526 - accuracy: 0.6746 - val_loss: 0.3201 - val_accuracy: 0.8788
# Epoch 2/20
# 204/204 [==============================] - 488s 2s/step - loss: 0.4091 - accuracy: 0.8346 - val_loss: 0.3416 - val_accuracy: 0.8719
# Epoch 3/20
# 204/204 [==============================] - 484s 2s/step - loss: 0.3536 - accuracy: 0.8618 - val_loss: 0.3806 - val_accuracy: 0.8725
# Epoch 4/20
# 204/204 [==============================] - 486s 2s/step - loss: 0.2675 - accuracy: 0.8935 - val_loss: 0.2325 - val_accuracy: 0.9206
# Epoch 5/20
# 204/204 [==============================] - 518s 3s/step - loss: 0.2524 - accuracy: 0.9016 - val_loss: 0.1614 - val_accuracy: 0.9450
# Epoch 6/20
# 204/204 [==============================] - 485s 2s/step - loss: 0.2304 - accuracy: 0.9110 - val_loss: 0.2138 - val_accuracy: 0.9262
# Epoch 7/20
# 204/204 [==============================] - 489s 2s/step - loss: 0.2204 - accuracy: 0.9158 - val_loss: 0.2596 - val_accuracy: 0.9131
# Epoch 8/20
# 204/204 [==============================] - 486s 2s/step - loss: 0.1997 - accuracy: 0.9239 - val_loss: 0.1899 - val_accuracy: 0.9394
# Epoch 9/20
# 204/204 [==============================] - 486s 2s/step - loss: 0.1964 - accuracy: 0.9249 - val_loss: 0.1460 - val_accuracy: 0.9475
# Epoch 10/20
# 204/204 [==============================] - 486s 2s/step - loss: 0.1689 - accuracy: 0.9366 - val_loss: 0.1354 - val_accuracy: 0.9563
# Epoch 11/20
# 204/204 [==============================] - 486s 2s/step - loss: 0.1576 - accuracy: 0.9422 - val_loss: 0.1715 - val_accuracy: 0.9413
# Epoch 12/20
# 204/204 [==============================] - 483s 2s/step - loss: 0.1425 - accuracy: 0.9472 - val_loss: 0.1431 - val_accuracy: 0.9563
# Epoch 13/20
# 204/204 [==============================] - 469s 2s/step - loss: 0.1493 - accuracy: 0.9465 - val_loss: 0.1146 - val_accuracy: 0.9569
# Epoch 14/20
# 204/204 [==============================] - 490s 2s/step - loss: 0.1348 - accuracy: 0.9541 - val_loss: 0.1957 - val_accuracy: 0.9350
# Epoch 15/20
# 204/204 [==============================] - 461s 2s/step - loss: 0.1315 - accuracy: 0.9526 - val_loss: 0.1212 - val_accuracy: 0.9656
# Epoch 16/20
# 204/204 [==============================] - 463s 2s/step - loss: 0.1401 - accuracy: 0.9485 - val_loss: 0.1453 - val_accuracy: 0.9513
# Epoch 17/20
# 204/204 [==============================] - 528s 3s/step - loss: 0.1269 - accuracy: 0.9550 - val_loss: 0.0947 - val_accuracy: 0.9656
# Epoch 18/20
# 204/204 [==============================] - 510s 3s/step - loss: 0.1233 - accuracy: 0.9547 - val_loss: 0.1632 - val_accuracy: 0.9431
# Epoch 19/20
# 204/204 [==============================] - 589s 3s/step - loss: 0.1285 - accuracy: 0.9532 - val_loss: 0.1450 - val_accuracy: 0.9563
# Epoch 20/20
# 204/204 [==============================] - 1698s 8s/step - loss: 0.1234 - accuracy: 0.9553 - val_loss: 0.1070 - val_accuracy: 0.9638

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Corn___Common_Rust',
#  'Corn___Gray_Leaf_Spot',
#  'Corn___Healthy',
#  'Corn___Leaf_Blight',
#  'Invalid']

# %%
def evaluate_model(model, test_dataset):
    y_true = []
    y_pred = []

    for images, labels in test_dataset:
        predictions = model.predict(images)
        y_true.extend(labels)
        y_pred.extend(predictions.argmax(axis=1))

    precision = precision_score(y_true, y_pred, average='micro')
    recall = recall_score(y_true, y_pred, average='micro')
    f1 = f1_score(y_true, y_pred, average='micro')
    accuracy = accuracy_score(y_true, y_pred)

    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1 Score: {f1}')
    print(f'Accuracy: {accuracy}')


def plot_confusion_matrix(model, test_dataset,class_names):
    y_true = []
    y_pred = []

    for images, labels in test_dataset:
        predictions = model.predict(images)
        y_true.extend(labels)
        y_pred.extend(predictions.argmax(axis=1))

    cm = confusion_matrix(y_true, y_pred)

    # Plot the confusion matrix
    #labels = [str(i) for i in range(n_class)]  # Assuming classes are labeled 0, 1, 2, ...
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
plot_confusion_matrix(model, test_dataset,class_names)
evaluate_model(model, test_dataset)
# Out:
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 272ms/step
# 2/2 [==============================] - 1s 265ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 251ms/step
# 2/2 [==============================] - 1s 259ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 275ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 273ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 278ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 263ms/step
# 2/2 [==============================] - 1s 275ms/step
# 1/1 [==============================] - 0s 234ms/step
# 2/2 [==============================] - 1s 268ms/step
# 2/2 [==============================] - 1s 285ms/step
# 2/2 [==============================] - 1s 263ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 258ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 264ms/step
# 2/2 [==============================] - 1s 275ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 287ms/step
# 2/2 [==============================] - 1s 284ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 256ms/step
# 1/1 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 276ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 270ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 275ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 272ms/step
# 2/2 [==============================] - 1s 249ms/step
# 2/2 [==============================] - 1s 264ms/step
# 2/2 [==============================] - 1s 256ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 267ms/step
# Precision: 0.9644859813084112
# Recall: 0.9644859813084112
# F1 Score: 0.9644859813084112
# Accuracy: 0.9644859813084112

# %%
#import numpy as np
#for image_batch,label_batch in test_dataset.take(1):
 #   batch_predict=model.predict(image_batch)

 #   print(batch_predict[0])

 # first_label=label_batch[0].numpy()

 #print("actual Label: ",class_names[first_label])
#print("predicted Label: ",class_names[np.argmax(batch_predict[0])])
#print("Confidence Label: ",np.argmax(batch_predict[0]))

# %%
#len(history.history['accuracy'])

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
        class_names = dataset.class_names

        plt.figure(figsize=(5, 5))
  #  for images, labels in test_dataset.take(1):
   # for i in range(9):
   #     ax = plt.subplot(3, 3, i + 1)
    
        plt.imshow(images[5].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 48ms/step
# (-0.5, 255.5, 255.5, -0.5)

# %%
#model_version=2
#model.save(f"C:/Users/user/jupiter/Crop___DIsease/model/{model_version}")

# %%
model_version=3
model.save(f"C:\\Users\\User\\Downloads\\Project\\project model\\corn/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\User\Downloads\Project\project model\corn/3\assets
# INFO:tensorflow:Assets written to: C:\Users\User\Downloads\Project\project model\corn/3\assets

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model_1 = converter.convert()

with open(f"C:\\Users\\User\\Downloads\\Project\\project model\\corn/{model_version}/corn_model.tflite", 'wb') as f:
  f.write(tflite_model_1)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\User\AppData\Local\Temp\tmp36eyhrwz\assets
# INFO:tensorflow:Assets written to: C:\Users\User\AppData\Local\Temp\tmp36eyhrwz\assets
